# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('Bundesliga_2023-2024_player_data.csv',index_col='index')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1988 entries, 0 to 15
# Data columns (total 53 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Player     1988 non-null   object
#  1   #          1988 non-null   float64
#  2   Nation     1988 non-null   object
#  3   Pos        1988 non-null   object
#  4   Age        1988 non-null   object
#  5   Min        1988 non-null   int64
#  6   Gls        1988 non-null   int64
#  7   Ast        1988 non-null   int64
#  8   PK         1988 non-null   int64
#  9   PKatt      1988 non-null   int64
#  10  Sh         1988 non-null   int64
#  11  SoT        1988 non-null   int64
#  12  CrdY       1988 non-null   int64
#  13  CrdR       1988 non-null   int64
#  14  Touches    1988 non-null   int64
#  15  Tkl        1988 non-null   int64
#  16  Int        1988 non-null   int64
#  17  Blocks     1988 non-null   int64
#  18  xG         1988 non-null   float64
#  19  npxG       1988 non-null   float64
# ...

# %%
df.head()
# Out:
#                 Player     #  Nation Pos     Age  Min  Gls  Ast  PK  PKatt  \
# index
# 0       Marvin Ducksch   7.0  de GER  FW  29-164   90    0    0   0      0
# 1      Niclas Füllkrug  11.0  de GER  FW  30-190   90    0    0   0      0
# 2         Anthony Jung   3.0  de GER  LW  31-288   78    0    0   0      0
# 3           Leon Opitz  35.0  de GER  LW  18-129   12    0    0   0      0
# 4      Mitchell Weiser   8.0  de GER  RW  29-119   58    0    0   0      0
#
#        ...  Att_y.2  Launch%.1  AvgLen.1  Opp  Stp  Stp%  #OPA  AvgDist  home  \
# index  ...
# 0      ...      NaN        NaN       NaN  NaN  NaN   NaN   NaN      NaN     1
# 1      ...      NaN        NaN       NaN  NaN  NaN   NaN   NaN      NaN     1
# 2      ...      NaN        NaN       NaN  NaN  NaN   NaN   NaN      NaN     1
# 3      ...      NaN        NaN       NaN  NaN  NaN   NaN   NaN      NaN     1
# 4      ...      NaN        NaN       NaN  NaN  NaN   NaN   NaN      NaN     1
#
#        game_id
# index
# ...

# %%
df['Player'].loc[df['Gls']>2]
# Out:
# index
# 0      Kevin Behrens
# 0    Serhou Guirassy
# 0         Harry Kane
# 0    Serhou Guirassy
# Name: Player, dtype: object
