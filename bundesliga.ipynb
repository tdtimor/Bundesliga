# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('Bundesliga_2023-2024.csv')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63 entries, 0 to 62
# Data columns (total 38 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Wk               63 non-null     float64
#  1   Day              63 non-null     object
#  2   Date             63 non-null     object
#  3   Time             63 non-null     object
#  4   Home             63 non-null     object
#  5   xG_x             63 non-null     float64
#  6   xG_y             63 non-null     float64
#  7   Away             63 non-null     object
#  8   Attendance       59 non-null     float64
#  9   Venue            63 non-null     object
#  10  Referee          63 non-null     object
#  11  game_id          63 non-null     int64
#  12  Score_x          63 non-null     int64
#  13  Score_y          63 non-null     int64
#  14  Fouls_x          63 non-null     float64
#  15  Corners_x        63 non-null     float64
# ...

# %%
data['Wk']=data['Wk'].astype('int')

# %%
data['Wk'].unique()
# Out:
# array([1, 2, 3, 4, 5, 6, 7])

# %%
data.head()
# Out:
#    Wk  Day        Date   Time           Home  xG_x  xG_y           Away  \
# 0   1  Fri  2023-08-18  20:30  Werder Bremen   0.6   2.8  Bayern Munich
# 1   1  Sat  2023-08-19  15:30     Leverkusen   1.4   1.6     RB Leipzig
# 2   1  Sat  2023-08-19  15:30      Wolfsburg   2.2   1.2     Heidenheim
# 3   1  Sat  2023-08-19  15:30      Stuttgart   3.0   0.8         Bochum
# 4   1  Sat  2023-08-19  15:30       Augsburg   2.3   1.7     M'Gladbach
#
#    Attendance                    Venue  ... Crosses_y  Touches_y  Tackles_y  \
# 0     42100.0  Wohninvest Weserstadion  ...      18.0      811.0        3.0
# 1     29464.0                 BayArena  ...      13.0      691.0       16.0
# 2     22620.0         Volkswagen Arena  ...      24.0      655.0       20.0
# 3     53000.0                 MHPArena  ...       8.0      495.0       24.0
# 4     30660.0                WWK Arena  ...      19.0      506.0       10.0
#
# ...
